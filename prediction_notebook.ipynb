# %%
LOG_DATA_PKL    =  "data.pkl"
LOG_MODEL_PKL   =  "model.pkl"
LOG_METRICS_PKL =  "metrics.pkl"


MLFLOW_RUN_ID='b5c3bfd020664a9fad57829e121169aa'
MLFLOW_TRACKING_URI = '../models/mlruns'
CLUSTERS_YAML_PATH=r"C:\Users\DELL\Downloads\features_skills_clusters_description.yaml"

# %%
import os 
import sklearn
import pickle
import yaml

import pandas as pd

import mlflow
from mlflow.tracking import MlflowClient

# %%
mlflow.set_tracking_uri("file:./mlruns")

# %%
import mlflow

mlflow.set_tracking_uri("file:./mlruns")

experiments = mlflow.search_experiments()

for exp in experiments:
    print(exp.experiment_id, exp.name)
# Out:
# 445342063325317644 my_experiment
# 501784985225875548 my_experiment
# 0 Default

# %%
runs = mlflow.search_runs()

print(runs[['run_id']].head())
# Out:
# Empty DataFrame
# Columns: [run_id]
# Index: []
